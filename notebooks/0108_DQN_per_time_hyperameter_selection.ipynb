# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../policy_training_and_evaluation/estimation/0108_per_time_val_regression_summary.csv')

# %%
df['ac'] = df.policy_dir.apply(lambda x: float(x.split('ac')[1].split('-gamma')[0]))
df
# Out:
#    test_loss                                         policy_dir  \
# 0   0.338502  ../models/dqn_mimic-0108_roc_curve-g1-ac0.0e+0...
# 1   0.667348  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e+0...
# 2   0.327781  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...
# 3   0.197473  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...
# 4   0.206334  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...
# 5   0.281003  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...
# 6   0.220312  ../models/dqn_mimic-0108_roc_curve-g1-ac2.0e-0...
# 7   0.336834  ../models/dqn_mimic-0108_roc_curve-g1-ac2.0e-0...
# 8   0.250091  ../models/dqn_mimic-0108_roc_curve-g1-ac5.0e-0...
# 9   0.259185  ../models/dqn_mimic-0108_roc_curve-g1-ac5.0e-0...
#
#        identifier                               reward_estimator_dir  \
# 0  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 1  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 2  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 3  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 4  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 5  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 6  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 7  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 8  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 9  0108_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
#
#                                            cache_dir  action_cost_coef  \
# 0  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00000
# 1  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           1.00000
# 2  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.01000
# 3  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00100
# 4  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00010
# 5  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00001
# 6  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00200
# 7  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00020
# 8  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.05000
# 9  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00005
#
#    gain_coef  mean_agent_info_gains  mean_agent_action_costs  \
# 0          1              -0.000315                15.711585
# 1          1              -0.000090                 0.377168
# 2          1               0.000052                65.609161
# 3          1              -0.000668                12.645727
# 4          1               0.000024                39.810037
# 5          1               0.000128                67.995811
# 6          1              -0.000149                42.801649
# 7          1               0.000010                16.106417
# 8          1               0.000101                68.631344
# 9          1              -0.000097                11.975209
#
#    overall_agent_reward  mean_phy_info_gains  mean_phy_action_costs  \
# 0            -15.711900             0.000117              11.219239
# 1             -0.377258             0.000117              11.219239
# 2            -65.609109             0.000117              11.219239
# 3            -12.646395             0.000117              11.219239
# 4            -39.810013             0.000117              11.219239
# 5            -67.995683             0.000117              11.219239
# 6            -42.801798             0.000117              11.219239
# 7            -16.106407             0.000117              11.219239
# 8            -68.631244             0.000117              11.219239
# 9            -11.975306             0.000117              11.219239
#
#    overall_phy_reward  mean_rand_info_gains  mean_rand_action_costs  \
# 0          -11.219122              0.000055               43.812144
# 1          -11.219122              0.000055               43.812144
# 2          -11.219122              0.000055               43.812144
# 3          -11.219122              0.000055               43.812144
# 4          -11.219122              0.000055               43.812144
# 5          -11.219122              0.000055               43.812144
# 6          -11.219122              0.000055               43.812144
# 7          -11.219122              0.000055               43.812144
# 8          -11.219122              0.000055               43.812144
# 9          -11.219122              0.000055               43.812144
#
#    overall_rand_reward  mean_phy_real_info_gains       ac
# 0           -43.812089                  0.007337  0.00000
# 1           -43.812089                  0.007337  1.00000
# 2           -43.812089                  0.007337  0.01000
# 3           -43.812089                  0.007337  0.00100
# 4           -43.812089                  0.007337  0.00010
# 5           -43.812089                  0.007337  0.00001
# 6           -43.812089                  0.007337  0.00200
# 7           -43.812089                  0.007337  0.00020
# 8           -43.812089                  0.007337  0.05000
# 9           -43.812089                  0.007337  0.00005

# %%
df.policy_dir.values
# Out:
# array(['../models/dqn_mimic-0108_roc_curve-g1-ac0.0e+00-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac1.0e+00-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-02-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-03-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-04-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-05-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac2.0e-03-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac2.0e-04-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac5.0e-02-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/',
#        '../models/dqn_mimic-0108_roc_curve-g1-ac5.0e-05-gamma0.95-fold1.0-only_pos0-sd167-ad40-nn-10000-3-1-128-lr-0.0001-reg-0.001-0.7-s-512-5000-i-50-500-3-1/'],
#       dtype=object)

# %% [markdown]
# ### Action cost have no relationship with cost/gain

# %%
plt.figure(figsize=[12,8])
plt.scatter(df['mean_agent_info_gains'], df['mean_agent_action_costs'], c=np.log(df['ac'] + 1e-9))
plt.xlabel('info_gains', fontsize=20)
plt.ylabel('action_costs', fontsize=20)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Overall reward is dominated by action cost

# %%
selected_df = df[(df['mean_agent_info_gains'] > df['mean_phy_info_gains']) & (df['mean_agent_action_costs'] < df['mean_phy_action_costs']) ]
selected_df
# Out:
# Empty DataFrame
# Columns: [test_loss, policy_dir, identifier, reward_estimator_dir, cache_dir, action_cost_coef, gain_coef, mean_agent_info_gains, mean_agent_action_costs, overall_agent_reward, mean_phy_info_gains, mean_phy_action_costs, overall_phy_reward, mean_rand_info_gains, mean_rand_action_costs, overall_rand_reward, mean_phy_real_info_gains, ac]
# Index: []

# %%
selected_df['policy_dir'].values
# Out:
# array([], dtype=object)

# %% [markdown]
# ## Final plot

# %%
plt.figure(figsize=[12,8])
plt.scatter(df['mean_agent_info_gains'], df['mean_agent_action_costs'], color='b', )
plt.scatter(df['mean_phy_info_gains'], df['mean_phy_action_costs'], color='r')
plt.scatter(df['mean_rand_info_gains'], df['mean_rand_action_costs'], color='g')
plt.legend(loc='best')
plt.xlabel('info_gains', fontsize=20)
plt.ylabel('action_costs', fontsize=20)
plt.show()
