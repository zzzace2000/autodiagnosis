# %% [markdown]
# # Let only_pos_reward = 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../policy_training_and_evaluation/estimation/0109_per_time_val_regression_summary.csv')

# %%
df['ac'] = df.policy_dir.apply(lambda x: float(x.split('ac')[1].split('-gamma')[0]))
df
# Out:
#    test_loss                                         policy_dir  \
# 0   0.279748  ../models/dqn_mimic-0109_roc_curve-g1-ac0.0e+0...
# 1   0.571321  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e+0...
# 2   0.382735  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e-0...
# 3   0.243380  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e-0...
# 4   0.451018  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e-0...
# 5   0.275055  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e-0...
# 6   0.284339  ../models/dqn_mimic-0109_roc_curve-g1-ac1.0e-0...
#
#        identifier                               reward_estimator_dir  \
# 0  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 1  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 2  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 3  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 4  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 5  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 6  0109_per_time_  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
#
#                                            cache_dir  action_cost_coef  \
# 0  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00000
# 1  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           1.00000
# 2  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.10000
# 3  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.01000
# 4  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00100
# 5  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00010
# 6  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00001
#
#    gain_coef  mean_agent_info_gains  mean_agent_action_costs  \
# 0          1               0.000240                16.375671
# 1          1               0.000314                 0.058457
# 2          1               0.000352                 4.375981
# 3          1               0.000242                45.556340
# 4          1               0.000182                51.485877
# 5          1               0.000242                19.001558
# 6          1               0.000297                39.621889
#
#    overall_agent_reward  mean_phy_info_gains  mean_phy_action_costs  \
# 0            -16.375431             0.000532              11.219239
# 1             -0.058143             0.000532              11.219239
# 2             -4.375629             0.000532              11.219239
# 3            -45.556098             0.000532              11.219239
# 4            -51.485695             0.000532              11.219239
# 5            -19.001316             0.000532              11.219239
# 6            -39.621592             0.000532              11.219239
#
#    overall_phy_reward  mean_rand_info_gains  mean_rand_action_costs  \
# 0          -11.218707               0.00037                16.58217
# 1          -11.218707               0.00037                16.58217
# 2          -11.218707               0.00037                16.58217
# 3          -11.218707               0.00037                16.58217
# 4          -11.218707               0.00037                16.58217
# 5          -11.218707               0.00037                16.58217
# 6          -11.218707               0.00037                16.58217
#
#    overall_rand_reward  mean_phy_real_info_gains       ac
# 0             -16.5818                  0.055928  0.00000
# 1             -16.5818                  0.055928  1.00000
# 2             -16.5818                  0.055928  0.10000
# 3             -16.5818                  0.055928  0.01000
# 4             -16.5818                  0.055928  0.00100
# 5             -16.5818                  0.055928  0.00010
# 6             -16.5818                  0.055928  0.00001

# %% [markdown]
# ### Action cost have no relationship with cost/gain

# %%
plt.figure(figsize=[12,8])
plt.scatter(df['mean_agent_info_gains'], df['mean_agent_action_costs'], c=np.log(df['ac'] + 1e-9))
plt.xlabel('info_gains', fontsize=20)
plt.ylabel('action_costs', fontsize=20)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Final plot

# %%
plt.figure(figsize=[12,8])
plt.scatter(df['mean_agent_info_gains'], df['mean_agent_action_costs'], color='b', )
plt.scatter(df['mean_phy_info_gains'], df['mean_phy_action_costs'], color='r')
plt.scatter(df['mean_rand_info_gains'], df['mean_rand_action_costs'], color='g')
plt.legend(loc='best')
plt.xlabel('info_gains', fontsize=20)
plt.ylabel('action_costs', fontsize=20)
plt.show()

# %% [markdown]
# ## Predicted is 100 times smaller than the real info gain

# %%
df['mean_phy_info_gains'][0], df['mean_phy_real_info_gains'][0]
# Out:
# (0.0005324258397365867, 0.05592803899338103)

# %% [markdown]
# # old

# %%
# Out:
#    test_loss                                         policy_dir identifier  \
# 0   0.206334  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...      0108_
# 1   0.197473  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...      0108_
# 2   0.338502  ../models/dqn_mimic-0108_roc_curve-g1-ac0.0e+0...      0108_
# 3   0.327781  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...      0108_
# 4   0.281003  ../models/dqn_mimic-0108_roc_curve-g1-ac1.0e-0...      0108_
#
#                                 reward_estimator_dir  \
# 0  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 1  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 2  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 3  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
# 4  ../models/rew_m_normal1217-hl1-hu512-lr1e-06-r...
#
#                                            cache_dir  action_cost_coef  \
# 0  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00010
# 1  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00100
# 2  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00000
# 3  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.01000
# 4  ../RL_exp_cache/1128-30mins-24hrs-20order-rnn-...           0.00001
#
#    gain_coef  mean_agent_info_gains  mean_agent_action_costs  \
# 0          1              -0.000798                50.403968
# 1          1              -0.001416                31.501590
# 2          1              -0.001975                24.652147
# 3          1              -0.001037                53.574887
# 4          1               0.000178                55.417743
#
#    overall_agent_reward  mean_phy_info_gains  mean_phy_action_costs  \
# 0            -50.404767             -0.00014              46.477027
# 1            -31.503006             -0.00014              46.477027
# 2            -24.654121             -0.00014              46.477027
# 3            -53.575923             -0.00014              46.477027
# 4            -55.417565             -0.00014              46.477027
#
#    overall_phy_reward  mean_rand_info_gains  mean_rand_action_costs  \
# 0          -46.477167             -0.000305               61.724813
# 1          -46.477167             -0.000305               61.724813
# 2          -46.477167             -0.000305               61.724813
# 3          -46.477167             -0.000305               61.724813
# 4          -46.477167             -0.000305               61.724813
#
#    overall_rand_reward       ac
# 0           -61.725118  0.00010
# 1           -61.725118  0.00100
# 2           -61.725118  0.00000
# 3           -61.725118  0.01000
# 4           -61.725118  0.00001

# %%
plt.figure(figsize=[12,8])
plt.scatter(df['mean_agent_info_gains'], df['mean_agent_action_costs'], color=df.ac)
# plt.scatter(df['mean_phy_info_gains'], df['mean_phy_action_costs'], color='r')
# plt.scatter(df['mean_rand_info_gains'], df['mean_rand_action_costs'], color='g')
plt.legend(loc='best')
plt.xlabel('info_gains', fontsize=20)
plt.ylabel('action_costs', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f6cad58cd389> in <module>
#       6 plt.xlabel('info_gains', fontsize=20)
#       7 plt.ylabel('action_costs', fontsize=20)
# ----> 8 plt.colorbar()
#       9 plt.show()
#
# ~/anaconda3/envs/cu90/lib/python3.6/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2326         ax = gca()
#    2327
# -> 2328     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2329     return ret
#    2330 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# ~/anaconda3/envs/cu90/lib/python3.6/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2069                              'panchor']
#    2070         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2071         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2072
#    2073         self.sca(current_ax)
#
# ~/anaconda3/envs/cu90/lib/python3.6/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1397         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1398     else:
# -> 1399         cb = Colorbar(cax, mappable, **kwargs)
#    1400
#    1401     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# ~/anaconda3/envs/cu90/lib/python3.6/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#     918         # Ensure the given mappable's norm has appropriate vmin and vmax set
#     919         # even if mappable.draw has not yet been called.
# --> 920         mappable.autoscale_None()
#     921
#     922         self.mappable = mappable
#
# ~/anaconda3/envs/cu90/lib/python3.6/site-packages/matplotlib/cm.py in autoscale_None(self)
#     360         """
#     361         if self._A is None:
# --> 362             raise TypeError('You must first set_array for mappable')
#     363         self.norm.autoscale_None(self._A)
#     364         self.changed()
#
# TypeError: You must first set_array for mappable
