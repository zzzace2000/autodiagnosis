# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from utils.plotting import _plot_element
from database.MIMIC_cache_exp import MIMIC_cache_discretized_joint_exp_independent_measurement

# %%
def plot(plt_func, *args, **kwargs):
    plt.figure(figsize=[12,8])
    plt_func(*args)
    plt.grid(True)
    _plot_element(**kwargs)
    plt.show()

# %%
features = ["Albumin", "Bicarbonate", "Bilirubin", "Blood urea nitrogen", "CO2", "Calcium", 
            "Calcium ionized", "Capillary refill rate", "Chloride", "Cholesterol", "Creatinine",
            "Diastolic blood pressure", "Fraction inspired oxygen", "Glascow coma scale total",
            "Glucose", "Heart Rate", "Hemoglobin", "Lactate", "Magnesium", "Mean blood pressure",
            "Oxygen saturation", "Partial pressure of carbon dioxide", "Partial pressure of oxygen",
            "Partial thromboplastin time", "Platelets", "Potassium", "Prothrombin time", "Respiratory rate",
            "Systolic blood pressure", "Temperature", "Urine output", "Weight", "White blood cell count",
            "pH", "noise_0", "noise_1", "noise_2", "noise_3", "noise_4", "noise_5"]

# %%
agent_action_freq = [0.069205, 0.329928, 0.177276, 0.0, 0.166872, 0.058717, 0.086532,
                     0.048083, 0.006214, 0.018036, 0.000021, 0.054839, 0.092412, 0.075356,
                     0.100794, 0.996956, 0.139995, 0.009737, 0.002043, 0.158344, 0.000375, 
                     0.175087, 0.044371, 0.126963, 0.0, 0.286495, 0.0, 0.99756, 0.815238, 0.019225, 
                     0.066223, 0.181468, 0.0, 0.0, 0.002606, 0.004608, 0.00196, 0.0, 0.255593, 0.057299]

# %%
df = pd.DataFrame({'feature': features, 'agent_action_freq': agent_action_freq})

# %%
cashe_dir = '../RL_exp_cache/1024-15mins-24hrs-joint-indep-measurement-rnn-all-pataient/'

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True


with tf.Session(config=config) as sess:
        mimic_exp = MIMIC_cache_discretized_joint_exp_independent_measurement(cache_dir=cashe_dir)

        test_loader = mimic_exp.gen_test_experience(sess, batch_size=1000000, shuffle=False)
        for idx, the_dict in enumerate(test_loader):
            data_dict = the_dict
            break

# %%
data_dict.keys()
# Out:
# dict_keys(['cur_state', 'next_state', 'gain_per_action', 'prob_gain_per_action', 'std_gain_per_action', 'cur_action', 'next_action', 'labels', 'patient_inds', 'the_steps', 'total_steps', 'gain_joint', 'prob_joint', 'std_joint', 'prob_null', 'std_null', 'prev_prob_joint', 'prev_std_joint'])

# %%
# Calculate phy action freq
print(data_dict['cur_action'].shape)
df['phy_action_freq'] = np.mean(data_dict['cur_action'], axis=0)
# Out:
# (558038, 40)

# %%
len(np.mean(data_dict['cur_action'], axis=0))
# Out:
# 40

# %%
df = df.sort_values(['phy_action_freq'], ascending=False)
df['phy_action_rank'] = np.arange(len(features))
df = df.sort_values(['agent_action_freq'], ascending=False)
df['agent_action_rank'] = np.arange(len(features))

# %%
df
# Out:
#                                feature  agent_action_freq  phy_action_freq  \
# 27                    Respiratory rate           0.997560         0.220523
# 15                          Heart Rate           0.996956         0.224076
# 28             Systolic blood pressure           0.815238         0.212301
# 1                          Bicarbonate           0.329928         0.012101
# 25                           Potassium           0.286495         0.014870
# 38                             noise_4           0.255593         0.050414
# 31                              Weight           0.181468         0.005677
# 2                            Bilirubin           0.177276         0.002953
# 21  Partial pressure of carbon dioxide           0.175087         0.005817
# 4                                  CO2           0.166872         0.005862
# 19                 Mean blood pressure           0.158344         0.209817
# 16                          Hemoglobin           0.139995         0.015304
# 23         Partial thromboplastin time           0.126963         0.007209
# 14                             Glucose           0.100794         0.045250
# 12            Fraction inspired oxygen           0.092412         0.004910
# 6                      Calcium ionized           0.086532         0.004337
# 13            Glascow coma scale total           0.075356         0.034609
# 0                              Albumin           0.069205         0.001417
# 30                        Urine output           0.066223         0.116438
# 5                              Calcium           0.058717         0.010157
# 39                             noise_5           0.057299         0.050050
# 11            Diastolic blood pressure           0.054839         0.212116
# 7                Capillary refill rate           0.048083         0.000674
# 22          Partial pressure of oxygen           0.044371         0.003684
# 29                         Temperature           0.019225         0.061490
# 9                          Cholesterol           0.018036         0.000192
# 17                             Lactate           0.009737         0.001928
# 8                             Chloride           0.006214         0.012472
# 35                             noise_1           0.004608         0.050463
# 34                             noise_0           0.002606         0.050319
# 18                           Magnesium           0.002043         0.015936
# 36                             noise_2           0.001960         0.050294
# 20                   Oxygen saturation           0.000375         0.208497
# 10                          Creatinine           0.000021         0.015965
# 26                    Prothrombin time           0.000000         0.006700
# 33                                  pH           0.000000         0.009195
# 32              White blood cell count           0.000000         0.011288
# 24                           Platelets           0.000000         0.015526
# 37                             noise_3           0.000000         0.050522
# 3                  Blood urea nitrogen           0.000000         0.012225
#
#     phy_action_rank  agent_action_rank
# 27                1                  0
# 15                0                  1
# 28                2                  2
# 1                23                  3
# 25               20                  4
# 38               10                  5
# 31               31                  6
# 2                35                  7
# 21               30                  8
# 4                29                  9
# 19                4                 10
# 16               19                 11
# 23               27                 12
# 14               14                 13
# 12               32                 14
# 6                33                 15
# 13               15                 16
# 0                37                 17
# 30                6                 18
# 5                25                 19
# 39               13                 20
# 11                3                 21
# 7                38                 22
# 22               34                 23
# 29                7                 24
# 9                39                 25
# 17               36                 26
# 8                21                 27
# 35                9                 28
# 34               11                 29
# 18               17                 30
# 36               12                 31
# 20                5                 32
# 10               16                 33
# 26               28                 34
# 33               26                 35
# 32               24                 36
# 24               18                 37
# 37                8                 38
# 3                22                 39

# %%
exp_df = pd.DataFrame({k: data_dict[k] for k in ['patient_inds', 'labels', 'the_steps', 'total_steps']})
patient_final_status  = exp_df.groupby('patient_inds')['labels'].apply(lambda x: max(x))

live_patient_inds = patient_final_status[patient_final_status != 1]
dead_patient_inds = patient_final_status[patient_final_status == 1]

exp_df_live = exp_df.join(live_patient_inds, on='patient_inds', how='right', rsuffix='_final')
exp_df_dead = exp_df.join(dead_patient_inds, on='patient_inds', how='right', rsuffix='_final')

phy_action_freq_live = np.mean(data_dict['cur_action'][exp_df_live.index], axis=0)
phy_action_freq_dead = np.mean(data_dict['cur_action'][exp_df_dead.index], axis=0)

# %%
print('number of patient lived')
len(live_patient_inds)
# Out:
# number of patient lived
# 5554

# %%
print('number of patient died')
sum(dead_patient_inds)
# Out:
# number of patient died
# 522

# %%
action_freq_live_and_dead = pd.DataFrame({'phy_action_freq_live': phy_action_freq_live,
                                         'phy_action_freq_dead': phy_action_freq_dead,
                                         'feature_name': features})
action_freq_live_and_dead['precentage_increase'] = (action_freq_live_and_dead['phy_action_freq_dead'] - action_freq_live_and_dead['phy_action_freq_live'])/ action_freq_live_and_dead['phy_action_freq_live']

# %%
action_freq_live_and_dead = action_freq_live_and_dead.sort_values(['phy_action_freq_live'], ascending=False)
action_freq_live_and_dead['phy_action_rank_live'] = np.arange(len(features))

action_freq_live_and_dead = action_freq_live_and_dead.sort_values(['phy_action_freq_dead'], ascending=False)
action_freq_live_and_dead['phy_action_rank_dead'] = np.arange(len(features))

# %%
action_freq_live_and_dead
# Out:
#     phy_action_freq_live  phy_action_freq_dead  \
# 15              0.221221              0.254447
# 27              0.217662              0.250944
# 28              0.209740              0.239538
# 11              0.209579              0.239100
# 19              0.207264              0.236973
# 20              0.207776              0.216164
# 30              0.116166              0.119331
# 29              0.060877              0.068016
# 35              0.049351              0.062282
# 36              0.049188              0.062053
# 38              0.049330              0.061949
# 37              0.049494              0.061448
# 39              0.049051              0.060677
# 34              0.049404              0.060051
# 14              0.044711              0.050981
# 13              0.034463              0.036156
# 33              0.007377              0.028524
# 4               0.004317              0.022290
# 21              0.004309              0.021852
# 10              0.015850              0.017181
# 18              0.015833              0.017035
# 25              0.014676              0.016931
# 24              0.015405              0.016806
# 16              0.015198              0.016431
# 22              0.002700              0.014158
# 8               0.012380              0.013449
# 1               0.011998              0.013199
# 3               0.012139              0.013136
# 12              0.004193              0.012532
# 5               0.009993              0.011906
# 32              0.011241              0.011781
# 6               0.003784              0.010217
# 23              0.006948              0.009988
# 26              0.006485              0.008987
# 17              0.001312              0.008486
# 2               0.002707              0.005567
# 31              0.005691              0.005526
# 0               0.001270              0.002982
# 7               0.000690              0.000500
# 9               0.000208              0.000021
#
#                           feature_name  precentage_increase  \
# 15                          Heart Rate             0.150193
# 27                    Respiratory rate             0.152903
# 28             Systolic blood pressure             0.142071
# 11            Diastolic blood pressure             0.140857
# 19                 Mean blood pressure             0.143340
# 20                   Oxygen saturation             0.040371
# 30                        Urine output             0.027243
# 29                         Temperature             0.117279
# 35                             noise_1             0.262024
# 36                             noise_2             0.261536
# 38                             noise_4             0.255813
# 37                             noise_3             0.241523
# 39                             noise_5             0.237009
# 34                             noise_0             0.215512
# 14                             Glucose             0.140242
# 13            Glascow coma scale total             0.049113
# 33                                  pH             2.866511
# 4                                  CO2             4.163304
# 21  Partial pressure of carbon dioxide             4.071085
# 10                          Creatinine             0.083963
# 18                           Magnesium             0.075952
# 25                           Potassium             0.153648
# 24                           Platelets             0.090914
# 16                          Hemoglobin             0.081135
# 22          Partial pressure of oxygen             4.244489
# 8                             Chloride             0.086310
# 1                          Bicarbonate             0.100068
# 3                  Blood urea nitrogen             0.082124
# 12            Fraction inspired oxygen             1.988347
# 5                              Calcium             0.191486
# 32              White blood cell count             0.047992
# 6                      Calcium ionized             1.700263
# 23         Partial thromboplastin time             0.437504
# 26                    Prothrombin time             0.385732
# 17                             Lactate             5.470467
# 2                            Bilirubin             1.056293
# 31                              Weight            -0.029119
# 0                              Albumin             1.347083
# 7                Capillary refill rate            -0.274837
# 9                          Cholesterol            -0.899663
#
#     phy_action_rank_live  phy_action_rank_dead
# 15                     0                     0
# 27                     1                     1
# 28                     2                     2
# 11                     3                     3
# 19                     5                     4
# 20                     4                     5
# 30                     6                     6
# 29                     7                     7
# 35                    10                     8
# 36                    12                     9
# 38                    11                    10
# 37                     8                    11
# 39                    13                    12
# 34                     9                    13
# 14                    14                    14
# 13                    15                    15
# 33                    26                    16
# 4                     30                    17
# 21                    31                    18
# 10                    16                    19
# 18                    17                    20
# 25                    20                    21
# 24                    18                    22
# 16                    19                    23
# 22                    35                    24
# 8                     21                    25
# 1                     23                    26
# 3                     22                    27
# 12                    32                    28
# 5                     25                    29
# 32                    24                    30
# 6                     33                    31
# 23                    27                    32
# 26                    28                    33
# 17                    36                    34
# 2                     34                    35
# 31                    29                    36
# 0                     37                    37
# 7                     38                    38
# 9                     39                    39

# %%
less_than = exp_df_dead.loc[exp_df_dead['the_steps'] < exp_df_dead['total_steps'] / 2]
bigger = exp_df_dead.loc[(exp_df_dead['the_steps'] > exp_df_dead['total_steps'] / 2)]# & (exp_df_dead['the_steps'] < exp_df_dead['total_steps'] * 3 / 5)]

phy_action_freq_less = np.mean(data_dict['cur_action'][less_than.index], axis=0)
phy_action_freq_bigger = np.mean(data_dict['cur_action'][bigger.index], axis=0)

# %%
action_freq_less_and_bigger = pd.DataFrame({'phy_action_freq_less': phy_action_freq_less,
                                         'phy_action_freq_bigger': phy_action_freq_bigger,
                                         'feature_name': features})
action_freq_less_and_bigger['precentage_increase'] = (action_freq_less_and_bigger['phy_action_freq_bigger'] - action_freq_less_and_bigger['phy_action_freq_less'])/ action_freq_less_and_bigger['phy_action_freq_less']

action_freq_less_and_bigger = action_freq_less_and_bigger.sort_values(['phy_action_freq_less'], ascending=False)
action_freq_less_and_bigger['phy_action_rank_less'] = np.arange(len(features))

action_freq_less_and_bigger = action_freq_less_and_bigger.sort_values(['phy_action_freq_bigger'], ascending=False)
action_freq_less_and_bigger['phy_action_rank_bigger'] = np.arange(len(features))

# %%
action_freq_less_and_bigger
# Out:
#     phy_action_freq_less  phy_action_freq_bigger  \
# 15              0.260562                0.248339
# 27              0.258062                0.243867
# 28              0.251729                0.226959
# 11              0.251479                0.226320
# 19              0.249313                0.224233
# 20              0.238563                0.192845
# 30              0.138072                0.100213
# 35              0.062745                0.061712
# 36              0.063870                0.060094
# 39              0.061495                0.059881
# 37              0.063870                0.059242
# 34              0.061162                0.058859
# 29              0.077244                0.058518
# 38              0.065870                0.058049
# 14              0.060995                0.040673
# 13              0.040997                0.031175
# 33              0.032497                0.024319
# 4               0.025540                0.018825
# 21              0.025040                0.018441
# 25              0.020957                0.012564
# 18              0.021415                0.012266
# 10              0.021790                0.012181
# 24              0.021123                0.012138
# 22              0.016207                0.011925
# 16              0.021123                0.011371
# 12              0.014790                0.010179
# 8               0.016915                0.009710
# 3               0.016624                0.009370
# 1               0.016749                0.009370
# 6               0.011124                0.009072
# 5               0.014832                0.008731
# 32              0.015207                0.008049
# 23              0.012666                0.007155
# 31              0.004333                0.006772
# 26              0.011166                0.006644
# 17              0.010291                0.006559
# 2               0.006458                0.004514
# 0               0.003500                0.002257
# 7               0.000625                0.000383
# 9               0.000042                0.000000
#
#                           feature_name  precentage_increase  \
# 15                          Heart Rate            -0.046909
# 27                    Respiratory rate            -0.055005
# 28             Systolic blood pressure            -0.098399
# 11            Diastolic blood pressure            -0.100043
# 19                 Mean blood pressure            -0.100593
# 20                   Oxygen saturation            -0.191641
# 30                        Urine output            -0.274197
# 35                             noise_1            -0.016458
# 36                             noise_2            -0.059120
# 39                             noise_5            -0.026248
# 37                             noise_3            -0.072456
# 34                             noise_0            -0.037654
# 29                         Temperature            -0.242424
# 38                             noise_4            -0.118721
# 14                             Glucose            -0.333175
# 13            Glascow coma scale total            -0.239559
# 33                                  pH            -0.251674
# 4                                  CO2            -0.262926
# 21  Partial pressure of carbon dioxide            -0.263517
# 25                           Potassium            -0.400480
# 18                           Magnesium            -0.427232
# 10                          Creatinine            -0.440998
# 24                           Platelets            -0.425373
# 22          Partial pressure of oxygen            -0.264203
# 16                          Hemoglobin            -0.461665
# 12            Fraction inspired oxygen            -0.311793
# 8                             Chloride            -0.425939
# 3                  Blood urea nitrogen            -0.436363
# 1                          Bicarbonate            -0.440570
# 6                      Calcium ionized            -0.184512
# 5                              Calcium            -0.411355
# 32              White blood cell count            -0.470680
# 23         Partial thromboplastin time            -0.435082
# 31                              Weight             0.562835
# 26                    Prothrombin time            -0.404970
# 17                             Lactate            -0.362657
# 2                            Bilirubin            -0.300925
# 0                              Albumin            -0.355020
# 7                Capillary refill rate            -0.386661
# 9                          Cholesterol            -1.000000
#
#     phy_action_rank_less  phy_action_rank_bigger
# 15                     0                       0
# 27                     1                       1
# 28                     2                       2
# 11                     3                       3
# 19                     4                       4
# 20                     5                       5
# 30                     6                       6
# 35                    11                       7
# 36                    10                       8
# 39                    12                       9
# 37                     9                      10
# 34                    13                      11
# 29                     7                      12
# 38                     8                      13
# 14                    14                      14
# 13                    15                      15
# 33                    16                      16
# 4                     17                      17
# 21                    18                      18
# 25                    23                      19
# 18                    20                      20
# 10                    19                      21
# 24                    21                      22
# 22                    27                      23
# 16                    22                      24
# 12                    30                      25
# 8                     24                      26
# 3                     26                      27
# 1                     25                      28
# 6                     33                      29
# 5                     29                      30
# 32                    28                      31
# 23                    31                      32
# 31                    36                      33
# 26                    32                      34
# 17                    34                      35
# 2                     35                      36
# 0                     37                      37
# 7                     38                      38
# 9                     39                      39
